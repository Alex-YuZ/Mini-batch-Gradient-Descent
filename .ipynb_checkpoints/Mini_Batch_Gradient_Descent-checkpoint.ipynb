# %%
import os
os.chdir('projects_on_GitHub/Machine_learning/Mini_Batch_Gradient_Descent')

# %% [markdown]
# ## Explore the dataset

# %%
data = np.loadtxt('data.csv', delimiter=',')
data[:10, :]
# Out:
# array([[-7.24070e-01,  2.23863e+00],
#        [-2.40724e+00, -1.56000e-03],
#        [ 2.64837e+00,  3.01665e+00],
#        [ 3.60920e-01,  2.31019e+00],
#        [ 6.73120e-01,  2.05950e+00],
#        [-4.54600e-01,  1.24736e+00],
#        [ 2.20168e+00,  2.82497e+00],
#        [ 1.15605e+00,  2.21802e+00],
#        [ 5.06940e-01,  1.43644e+00],
#        [-8.59520e-01,  1.74980e+00]])

# %%
data.shape
# Out:
# (100, 2)

# %%
X = data[:, :-1]
y = data[:, -1]
_ = plt.scatter(X, y)

# %%
n_point = X.shape[0]
np.random.choice(range(10),20)
# Out:
# array([8, 9, 4, 8, 7, 8, 5, 1, 4, 8, 7, 6, 7, 5, 8, 0, 8, 6, 8, 4])

# %% [markdown]
# ## Mean Sqaured Error Step

# %%
def MSEStep(X, y, W, b, learning_rate = .005):
    """
    This function implements the gradient descent step for squared error as a
    performance metric.
    
    Parameters
    ----------
    X : array of predictor features
    y : array of outcome values
    W : predictor feature coefficients
    b : regression function intercept
    learn_rate : learning rate

    Returns
    -------
    W_new : predictor feature coefficients following gradient descent step
    b_new : intercept following gradient descent step
    """
    # compute the errors
    y_pred = np.matmul(X, W) + b
    error = y - y_pred
    
    # compute steps
    W_new = W + learning_rate * np.matmul(error, X)
    b_new = b + learning_rate * error.sum()
    
    return W_new, b_new

# %% [markdown]
# ## Mini-Batch Gradient Descent

# %%
def miniBatchGD(X, y, batch_size=20, learning_rate=.005, num_iter=25):
    """
    This function performs mini-batch gradient descent on a given dataset.

    Parameters
    X : array of predictor features
    y : array of outcome values
    batch_size : how many data points will be sampled for each iteration
    learn_rate : learning rate
    num_iter : number of batches used

    Returns
    regression_coef : array of slopes and intercepts generated by gradient
      descent procedure
    """
    n_points = X.shape[0]
    W = np.zeros(X.shape[1]) # coefficients
    b = 0 # intercept
    
    # run iterations
    regression_coef = [np.hstack((W,b))]
    for _ in range(num_iter):
        batch = np.random.choice(range(n_points), batch_size)
        X_batch = X[batch,:]
        y_batch = y[batch]
        W, b = MSEStep(X_batch, y_batch, W, b, learning_rate)
        regression_coef.append(np.hstack((W,b)))
    
    return regression_coef

# %% [markdown]
# ## Main Function

# %%
if __name__ == "__main__":
    # perform gradient descent
    data = np.loadtxt('data.csv', delimiter = ',')
    X = data[:,:-1]
    y = data[:,-1]
    regression_coef = miniBatchGD(X, y)
    
    # plot the result
    plt.figure()
    X_min = X.min()
    X_max = X.max()
    counter = len(regression_coef)
    for W, b in regression_coef:
        counter -= 1
        color = [1 - 0.92 ** counter for _ in range(3)]
        plt.plot([X_min, X_max],[X_min * W + b, X_max * W + b], color = color);
    plt.scatter(X, y, zorder = 3);
    plt.show()

# %%
# increase num_iter to 50
regression_coef = miniBatchGD(X, y, num_iter=50)

# plot the result
plt.figure()
X_min = X.min()
X_max = X.max()
counter = len(regression_coef)
for W, b in regression_coef:
    counter -= 1
    color = [1 - 0.92 ** counter for _ in range(3)]
    plt.plot([X_min, X_max],[X_min * W + b, X_max * W + b], color = color);
plt.scatter(X, y, zorder = 3);
plt.show()
